# %% [markdown]
# ### Data Analysis Using Pokemon Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("pokemon.csv")
df
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
name = "Samad"
age = 13

# using f strings
print(f'My name is {name} & age is {age}')
# using r strings
print(r'www.webiste.com\new_page.html')
# Out:
# My name is Samad & age is 13
# www.webiste.com\new_page.html

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'image_url', 'Id', 'Names', 'Type1', 'Type2', 'Total',
#        'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0           Id        Total           HP       Attack  \
# count  1194.000000  1194.000000  1194.000000  1194.000000  1194.000000
# mean    596.500000   492.746231   441.206868    70.883585    80.948911
# std     344.822418   293.719541   121.015326    26.861740    32.126164
# min       0.000000     1.000000   175.000000     1.000000     5.000000
# 25%     298.250000   235.250000   330.000000    52.000000    56.000000
# 50%     596.500000   486.500000   460.500000    70.000000    80.000000
# 75%     894.750000   741.750000   520.000000    85.000000   100.000000
# max    1193.000000  1010.000000  1125.000000   255.000000   190.000000
#
#            Defense      Sp. Atk      Sp. Def        Speed
# count  1194.000000  1194.000000  1194.000000  1194.000000
# mean     74.587102    72.881072    72.123953    69.782245
# std      30.678626    32.702411    27.628412    30.200828
# min       5.000000    10.000000    20.000000     5.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1194 non-null   int64
#  1   image_url   1194 non-null   object
#  2   Id          1194 non-null   int64
#  3   Names       1194 non-null   object
#  4   Type1       1194 non-null   object
#  5   Type2       652 non-null    object
#  6   Total       1194 non-null   int64
#  7   HP          1194 non-null   int64
#  8   Attack      1194 non-null   int64
#  9   Defense     1194 non-null   int64
#  10  Sp. Atk     1194 non-null   int64
#  11  Sp. Def     1194 non-null   int64
#  12  Speed       1194 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 121.4+ KB

# %%
# Exatract columm
# find null vaules in column
# print row
df[df["Type2"].isna()]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 4              4  https://img.pokemondb.net/sprites/sword-shield...    4
# 5              5  https://img.pokemondb.net/sprites/sword-shield...    5
# 9              9  https://img.pokemondb.net/sprites/sword-shield...    7
# 10            10  https://img.pokemondb.net/sprites/sword-shield...    8
# 11            11  https://img.pokemondb.net/sprites/sword-shield...    9
# ...          ...                                                ...  ...
# 1156        1156  https://img.pokemondb.net/sprites/scarlet-viol...  977
# 1163        1163  https://img.pokemondb.net/sprites/scarlet-viol...  982
# 1164        1164  https://img.pokemondb.net/sprites/scarlet-viol...  982
# 1181        1181  https://img.pokemondb.net/sprites/scarlet-viol...  999
# 1182        1182  https://img.pokemondb.net/sprites/scarlet-viol...  999
#
#                                Names   Type1 Type2  Total   HP  Attack  \
# ...

# %%
df.fillna("None", inplace= True)
df
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
df["Type1"].value_counts()
# find total number of values count for type2,speed,attack
# Out:
# Water       150
# Normal      131
# Grass       105
# Bug          91
# Psychic      82
# Fire         75
# Electric     73
# Rock         67
# Dark         56
# Fighting     50
# Dragon       49
# Ghost        47
# Ground       46
# Poison       45
# Ice          43
# Steel        43
# Fairy        31
# Flying       10
# Name: Type1, dtype: int64

# %% [markdown]
# ### Find names and type2 where type one is flying

# %%
df.loc[df["Type1"]== "Ice"][["Names", "Type2"]]
# Out:
#                                   Names    Type2
# 37           Sandshrew Alolan Sandshrew    Steel
# 39           Sandslash Alolan Sandslash    Steel
# 49                 Vulpix Alolan Vulpix     None
# 51           Ninetales Alolan Ninetales    Fairy
# 162          Mr. Mime Galarian Mr. Mime  Psychic
# 164                                Jynx  Psychic
# 191                            Articuno   Flying
# 281                              Swinub   Ground
# 282                           Piloswine   Ground
# 287                            Delibird   Flying
# 301                            Smoochum  Psychic
# 432                 Castform Snowy Form     None
# 444                             Snorunt     None
# 445                              Glalie     None
# 446                  Glalie Mega Glalie     None
# 447                              Spheal    Water
# 448                              Sealeo    Water
# 449                             Walrein    Water
# ...

# %% [markdown]
# ### Find names and speed where type1 is steel

# %%
df.loc[df["Type1"] == "Steel"][["Names", "Speed"]]
# Out:
#                          Names  Speed
# 69      Meowth Galarian Meowth     40
# 264                    Steelix     30
# 265       Steelix Mega Steelix     30
# 289                   Skarmory     70
# 374                     Mawile     50
# 375         Mawile Mega Mawile     50
# 376                       Aron     30
# 377                     Lairon     40
# 378                     Aggron     50
# 379         Aggron Mega Aggron     50
# 459                     Beldum     30
# 460                     Metang     50
# 461                  Metagross     70
# 462   Metagross Mega Metagross    110
# 465                  Registeel     50
# 476                    Jirachi    100
# 535                    Bronzor     23
# 536                   Bronzong     33
# 591                     Dialga     90
# 592        Dialga Origin Forme     90
# 723                      Klink     30
# 724                      Klang     50
# 725                  Klinklang     90
# 764                   Cobalion    108
# ...

# %% [markdown]
# ### Find Only names of Pokemons where type1 is ice

# %%
df[df["Type1"] == "Ice"]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 37            37  https://img.pokemondb.net/sprites/sword-shield...   27
# 39            39  https://img.pokemondb.net/sprites/sword-shield...   28
# 49            49  https://img.pokemondb.net/sprites/sword-shield...   37
# 51            51  https://img.pokemondb.net/sprites/sword-shield...   38
# 162          162  https://img.pokemondb.net/sprites/sword-shield...  122
# 164          164  https://img.pokemondb.net/sprites/sword-shield...  124
# 191          191  https://img.pokemondb.net/sprites/sword-shield...  144
# 281          281  https://img.pokemondb.net/sprites/sword-shield...  220
# 282          282  https://img.pokemondb.net/sprites/sword-shield...  221
# 287          287  https://img.pokemondb.net/sprites/sword-shield...  225
# 301          301  https://img.pokemondb.net/sprites/sword-shield...  238
# 432          432  https://img.pokemondb.net/sprites/sword-shield...  351
# ...

# %%
df.loc[df["Defense"] == df["Defense"].max()]
# Out:
#       Unnamed: 0                                          image_url   Id  \
# 1058        1058  https://img.pokemondb.net/sprites/sword-shield...  890
#
#                     Names   Type1   Type2  Total   HP  Attack  Defense  \
# 1058  Eternatus Eternamax  Poison  Dragon   1125  255     115      250
#
#       Sp. Atk  Sp. Def  Speed
# 1058      125      250    130

# %%
df.loc[df["Defense"] == df["Defense"].max()][["Names", "Type1", "Type2"]]
# Out:
#                     Names   Type1   Type2
# 1058  Eternatus Eternamax  Poison  Dragon

# %% [markdown]
# ### First Find column

# %%
df['Attack']
# Out:
# 190

# %% [markdown]
# ### 2nd to find column max value

# %%
df['Attack'].max()
# Out:
# 190

# %% [markdown]
# ### 3rd check for condition attack column where attack is maximum

# %%
df.loc[df["Attack"] == df["Attack"].max()]
# Out:
#      Unnamed: 0                                          image_url   Id  \
# 201         201  https://img.pokemondb.net/sprites/sword-shield...  150
#
#                     Names    Type1     Type2  Total   HP  Attack  Defense  \
# 201  Mewtwo Mega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed
# 201      154      100    130

# %%
df.loc[df["Attack"] == df["Attack"].max()][["Names", "Type1", "Type2"]]
# Out:
#                     Names    Type1     Type2
# 201  Mewtwo Mega Mewtwo X  Psychic  Fighting

# %% [markdown]
# ### We plot this to find the intersection of attack and defense

# %%
plt.plot(df["Attack"])      #Data Visula
plt.plot(df["Defense"])
plt.show()

# %%
e = df[df["Defense"] > 150]
e[df["Attack"] > 150]
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13400\1035470546.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   e[df["Attack"] > 150]
#      Unnamed: 0                                          image_url   Id  \
# 473         473  https://img.pokemondb.net/sprites/sword-shield...  383
#
#                       Names   Type1 Type2  Total   HP  Attack  Defense  \
# 473  Groudon Primal Groudon  Ground  Fire    770  100     180      160
#
#      Sp. Atk  Sp. Def  Speed
# 473      150       90     90

# %%
xpoint = np.array([0,6])
ypoint = np.array([0,250])

# %%
plt.plot(xpoint,ypoint, linestyle = "dotted")
plt.show()

# %%
plt.plot(xpoint,ypoint, linestyle = "dashed")
plt.show()

# %%
plt.plot(xpoint,ypoint, linestyle = "dashdot")
plt.show()

# %%
plt.plot(xpoint,ypoint, linestyle = "None")
plt.show()

# %%
plt.plot(xpoint,ypoint, color = "black")
plt.show()

# %%
x1 = np.array([0,1,2,3])
y1 = np.array([3,8,1,10])
x2 = np.array([0,1,2,3])
y2 = np.array([6,2,7,11])

plt.plot(x1,y1,x2,y2)
plt.title("Sports Watch Data")
plt.xlabel("Average Pluse")
plt.ylabel("Calorie Burnage")
plt.show()
