# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\hp\Desktop\supermarket_sales.xlsx")

# %%
df
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 0    692-92-5582      B  Mandalay        Member  Female
# 1    351-62-0822      B  Mandalay        Member  Female
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 4    319-50-3348      B  Mandalay        Normal  Female
# ..           ...    ...       ...           ...     ...
# 995  886-18-2897      A    Yangon        Normal  Female
# 996  745-74-0715      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total  \
# 0        Food_and_beverages       54.84         3   8.226  172.746
# 1       Fashion_accessories       14.48         4   2.896   60.816
# 2    Electronic_accessories       25.51         4   5.102  107.142
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
#Find Payment tpes in Dataset
df["Payment"].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
#Find the rows where paymment is cash
df.loc[df["Payment"] == "Cash"]
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 2    529-56-3974      B  Mandalay        Member    Male
# 3    299-46-1805      B  Mandalay        Member  Female
# 7    649-29-6775      B  Mandalay        Normal    Male
# 8    145-94-9061      B  Mandalay        Normal  Female
# 10   149-71-6266      B  Mandalay        Member    Male
# ..           ...    ...       ...           ...     ...
# 992  221-25-5073      A    Yangon        Normal  Female
# 993  809-46-1866      A    Yangon        Normal    Male
# 997  727-02-1313      A    Yangon        Member    Male
# 998  347-56-2442      A    Yangon        Normal    Male
# 999  849-09-3807      A    Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2    Electronic_accessories       25.51         4   5.1020  107.1420
# 3         Sports_and_travel       93.72         6  28.1160  590.4360
# 7       Fashion_accessories       33.52         1   1.6760   35.1960
# ...

# %%
# How many Cities in Dataset
df["City"].value_counts().sum()
# Out:
# 1000

# %%
#Find out customer type in dataset
df["Customer type"].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
#find branches in dataset
df['Branch'].unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
#find mode of rating in dataset where branch is B
m = df[df['Branch']=='B']["Rating"]

# %%
m.mode()
# Out:
# 0    5.1
# 1    6.5
# 2    8.9
# Name: Rating, dtype: float64

# %%
# Find the rows where gender is male and customer type is Memmber
df.loc[df["Gender"]== "Male"][df["Customer type"]=="Member"]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_856\554685201.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[df["Gender"]== "Male"][df["Customer type"]=="Member"]
#       Invoice ID Branch      City Customer type Gender  \
# 2    529-56-3974      B  Mandalay        Member   Male
# 10   149-71-6266      B  Mandalay        Member   Male
# 12   777-82-7220      B  Mandalay        Member   Male
# 16   370-41-7321      B  Mandalay        Member   Male
# 18   669-54-1719      B  Mandalay        Member   Male
# ..           ...    ...       ...           ...    ...
# 972  522-57-8364      A    Yangon        Member   Male
# 982  333-23-2632      A    Yangon        Member   Male
# 986  324-92-3863      A    Yangon        Member   Male
# 989  195-06-0432      A    Yangon        Member   Male
# 997  727-02-1313      A    Yangon        Member   Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# ...

# %%
df.loc[(df["Gender"]== "Male") & (df["Customer type"]=="Member")]
# Out:
#       Invoice ID Branch      City Customer type Gender  \
# 2    529-56-3974      B  Mandalay        Member   Male
# 10   149-71-6266      B  Mandalay        Member   Male
# 12   777-82-7220      B  Mandalay        Member   Male
# 16   370-41-7321      B  Mandalay        Member   Male
# 18   669-54-1719      B  Mandalay        Member   Male
# ..           ...    ...       ...           ...    ...
# 972  522-57-8364      A    Yangon        Member   Male
# 982  333-23-2632      A    Yangon        Member   Male
# 986  324-92-3863      A    Yangon        Member   Male
# 989  195-06-0432      A    Yangon        Member   Male
# 997  727-02-1313      A    Yangon        Member   Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 2    Electronic_accessories       25.51         4   5.1020  107.1420
# 10        Sports_and_travel       78.07         9  35.1315  737.7615
# 12       Home_and_lifestyle       30.12         8  12.0480  253.0080
# ...

# %%
df["Tax 5%"].sum()
# Out:
# 15379.369

# %%
df["Total"].median()
# Out:
# 253.848

# %%
df["Rating"].max()
# Out:
# 10.0

# %%
df[df["Rating"] ==max(df["Rating"])]["Product line"]
# Out:
# 21          Sports_and_travel
# 48          Sports_and_travel
# 279    Electronic_accessories
# 347         Sports_and_travel
# 794         Health_and_beauty
# Name: Product line, dtype: object

# %%
df.groupby(["Gender", "Payment"]).count()["Quantity"] #slicing 'Quantity'

# %%
df.groupby(["Branch", "City", "Customer type"]).count()
# Out:
#                                 Invoice ID  Gender  Product line  Unit price  \
# Branch City      Customer type
# A      Yangon    Member                167     167           167         167
#                  Normal                173     173           173         173
# B      Mandalay  Member                165     165           165         165
#                  Normal                167     167           167         167
# C      Naypyitaw Member                169     169           169         169
#                  Normal                159     159           159         159
#
#                                 Quantity  Tax 5%  Total  Date  Time  Payment  \
# Branch City      Customer type
# A      Yangon    Member              167     167    167   167   167      167
#                  Normal              173     173    173   173   173      173
# B      Mandalay  Member              165     165    165   165   165      165
# ...

# %%
df.groupby(["Gender", "Payment"]).agg(['count', 'sum', 'min' 'max'])['Quantity']  # list passed in aggregate function
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_856\987845914.py:1: FutureWarning: ['Date', 'Time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(["Gender", "Payment"]).agg(['count', 'sum', 'max'])['Quantity']  # list passed in aggregate function
#                     count   sum  max
# Gender Payment
# Female Cash           178  1004   10
#        Credit card    163   928   10
#        Ewallet        160   937   10
# Male   Cash           166   892   10
#        Credit card    148   794   10
#        Ewallet        185   955   10

# %%
df.groupby(["Gender", "Product line"]).agg(['count', 'sum', 'min', 'max'])['Payment']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_856\1881570078.py:1: FutureWarning: ['Date', 'Time'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(["Gender", "Product line"]).agg(['count', 'sum', 'min', 'max'])['Payment']
#                                count  \
# Gender Product line
# Female Electronic_accessories     84
#        Fashion_accessories        96
#        Food_and_beverages         90
#        Health_and_beauty          64
#        Home_and_lifestyle         79
#        Sports_and_travel          88
# Male   Electronic_accessories     86
#        Fashion_accessories        82
#        Food_and_beverages         84
#        Health_and_beauty          88
#        Home_and_lifestyle         81
#        Sports_and_travel          78
#
#                                                                              sum  \
# Gender Product line
# ...

# %%
#Types of graph : 6
#date and time error

# %%
df["Gender"].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
import seaborn as sns
#Countplot in categorical
sns.countplot(x='Gender', data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Product line', data=df)
#you can see glitches/overlapping in following plot
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
#use matplotlib and define argument
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5)) # inside tuple(width,height)
sns.countplot(x='Product line', data=df)
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=df, hue='Gender')
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Payment', data=df, hue='Gender')
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=df, hue='Gender', palette="PuBuGn_r")
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=df, hue='Gender', palette="PuBuGn_r", facecolor=(0,0,0,0) )
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=df, hue='Gender', palette="PuBuGn_r", facecolor=(0,0,0,0), linewidth=5, 
              edgecolor=sns.color_palette('dark', 3) )
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product line', data=df, hue='Gender', facecolor=(0,0,0,1), linewidth=5, 
              edgecolor=sns.color_palette('dark', 3) )
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
# Barplot in categorical

plt.figure(figsize=(15,5))
sns.barplot(x='Product line', y='Total', data=df)

#error line is shown here, for density
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
#draw a bargraph for Customer type and Rating, and hue is Gender
plt.figure(figsize=(15,5))
sns.barplot(x='Customer type', y= 'Rating', hue='Gender', data=df)
# sns.barplot(x='Customer type', y= 'Rating', data=df)
# Out:
# <Axes: xlabel='Customer type', ylabel='Rating'>

# %%
#draw a bargraph for city and quantity, and hue is Gender
sns.barplot(x='City', y='Quantity', hue='Payment', data=df)
# Out:
# <Axes: xlabel='City', ylabel='Quantity'>

# %%
#draw a bargraph for branch and total and hue is payment
sns.barplot(x='Branch', y='Total', hue='Payment', data=df)
# Out:
# <Axes: xlabel='Branch', ylabel='Total'>

# %%
df['Product line'].unique()
# Out:
# array(['Food_and_beverages', 'Fashion_accessories',
#        'Electronic_accessories', 'Sports_and_travel',
#        'Home_and_lifestyle', 'Health_and_beauty'], dtype=object)

# %%
#changing order of cols in barplot
plt.figure(figsize=(15,6))
sns.barplot(x='Product line', y='Total',data=df, order=['Electronic_accessories', 'Fashion_accessories', 'Food_and_beverages','Sports_and_travel','Home_and_lifestyle','Health_and_beauty'])
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
#changing order of cols in barplot using order
plt.figure(figsize=(15,6))
sns.barplot(x='Product line', y='Total',data=df, order=['Electronic_accessories', 'Fashion_accessories', 'Food_and_beverages','Sports_and_travel','Home_and_lifestyle','Health_and_beauty'],
            hue="Gender", hue_order=["Male", "Female"]  )
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
#changing hue order
plt.figure(figsize=(15,6))
sns.barplot(x='Product line', y='Total',data=df, order=['Electronic_accessories', 'Fashion_accessories', 'Food_and_beverages','Sports_and_travel','Home_and_lifestyle','Health_and_beauty'],
            hue="Payment", hue_order=["Ewallet", "Cash", "Credit card"]  )
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
# Boxplot tells mean median outliers

sns.boxplot(y='Total', data=df, width=0.2, showmeans=True, ) 
#first line tells mini value

#1st line of box tells first quartile 25% of data
#last line is max value

#2nd line is 2nd quartile is median

#3rd quartile

#green shows median
#black dot are outlier
# Out:
# <Axes: ylabel='Total'>

# %%
sns.boxplot(y='Total', data=df, width=0.2, showmeans=True, meanprops=
        
            
            {'marker':'o', 'markerfacecolor':'white', 'markersize':10, 'markeredgecolor':'black'})
# Out:
# <Axes: ylabel='Total'>

# %%
sns.boxplot(x='Payment', y='Total', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='Product line', y='Rating', hue='Payment', data=df)
#Results
# start from minimum, then first quartile, second quartile, third quartile, max
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(10,5))
#       2 sns.boxplot(x='Product line', y='Rating', hue='Payment', data=df)
#
# NameError: name 'plt' is not defined

# %%
df['Total'].describe() #check the mean value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Total'].describe()
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
# violin plot

sns.violinplot(y='Total', data=df) 

#the white dot indicates median and Black line shows the min and max value top for max

#kernel density estimation?
# Out:
# <Axes: ylabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', data=df , hue='Gender') #
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
#apply grid on above graph to check exact min max value

# %%
sns.violinplot(x='Payment',y='Total', data=df , hue='Gender', split=True) #split=True coombines two graphs
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.violinplot(x='Payment',y='Total', data=df , hue='Gender', split=True, inner='quartile') 
#lines shows % of quartiles, 1st, 2nd and 3rd
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
#combine box polts and line plot
sns.violinplot(x='Payment',y='Total', data=df, inner='quartile')
sns.boxplot(x='Payment', y='Total', hue='Gender', data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(data=df, y ='Total')
#dot represent on how much times is used no. of values :  5 two times then 2 dots for it

#kis number p kitni value moujood h is kernel density
# Out:
# <Axes: ylabel='Total'>

# %%
sns.stripplot(data=df, y ='Total', x='Payment') # y is numerical and x is categorical point/col

#at 200 density is greater
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %%
sns.stripplot(data=df, y ='Total', hue='Gender')
# Out:
# <Axes: ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.stripplot(data=df, y ='Total', x='Product line', hue='Customer type', dodge=True)
plt.grid()

# %%
# sns.stripplot(data=df, y ='Total', x='Product line', hue='Customer type', dodge=True, jitter=0.5) # jitter spread
# sns.stripplot(data=df, y ='Total', x='Product line', hue='Customer type', dodge=True, linewidth=0.5)

# %%
sns.boxplot(data=df, y ='Total', x='Product line', hue='Customer type', dodge=True)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
sns.stripplot(data=df, y ='Total', x='Product line', hue='Customer type', dodge=True)
sns.boxplot(data=df, y ='Total', x='Product line', hue='Customer type', dodge=True)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
