# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\hp\Desktop\laptop_data.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
#in this dtype is different
#we've to preprocessing object dtype of 'Weight'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.describe()

# %%
df.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
len(df.loc[df['Company']=='Apple'])
# Out:
# 21

# %%
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
#Manipulate values
# df['Ram']= df["Ram"].str.replace('GB','') #replace with empty str
df["Ram"].str.replace('GB','MB') #replace with empty str
# Out:
# 0        8MB
# 1        8MB
# 2        8MB
# 3       16MB
# 4        8MB
#         ...
# 1298     4MB
# 1299    16MB
# 1300     2MB
# 1301     6MB
# 1302     4MB
# Name: Ram, Length: 1303, dtype: object

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Weight']= df["Weight"].str.replace('kg','') 
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
#type casting
df['Ram']=df['Ram'].astype('int32')   #here in int32 , 32 represent range or 
df['Weight']=df['Weight'].astype('float32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 2
#       1 #type casting
# ----> 2 df['Ram']=df['Ram'].astype('int32')   #here in int32 , 32 represent range or
#       3 df['Weight']=df['Weight'].astype('float32')
#
# File E:\anaconda3\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
df

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df['Price'])  #distplot = gives bar and line both

# %%
df['Company'].value_counts()  #total no of laptops of each company

# %%
df['Company'].value_counts().plot(kind='bar')  # plot using through pandas not the matplotlib

# %%
sns.barplot(x=df['Company'], y=df['Price'])

# %%
sns.barplot(x=df['Company'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

#blackline on graph represent the density & shows it has highest ratio

# %%
#draw a line plot for price of apple
sns.lineplot(x=df['Company']=='Apple', y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# plt.plot(x=df.loc[df['Company']=='Apple'], y=df['Price'])

y=df.loc[df['Company']=='Apple']['Price']
plt.plot(y)
plt.title('Heading')
plt.xlabel('Density')
plt.ylabel('Price')
plt.show()

# %%
#draw a bar  chart for  values of TypeName
df['TypeName'].value_counts().plot(kind='bar')

# %%
#find the rows where os is windows 10
df.loc[df["OpSys"]=="Windows 10"]

# %%
df['Ram'].value_counts().plot(kind='pie')

# %%
df['Ram'].value_counts().plot(kind='bar')

# %%
x=df.loc[df['Company']=='HP']['Price']
plt.plot(x)

plt.show()

# %%
df.shape

# %%
x=df.loc[df['Company']=='HP']['Price']
import numpy as np
y= np.arange(len(x)) #in acc to hp's range
plt.plot(y,x)

plt.show()

# %%
import seaborn as sns

# %%
# sns.barplot(x=df["TypeName"])
sns.barplot(x=df["TypeName"], y=df['Price'])
plt.xticks(rotation='vertical')
plt.title('Laptop')
plt.show()

# %%
df['OpSys'].value_counts()

# %%
sns.barplot(x=df['OpSys'], y=df['Price'])
plt.xticks(rotation='vertical')

# %%
sns.distplot(x=df["Inches"])
plt.xticks(rotation='vertical')
plt.title('Laptop')
plt.show()

# %%
sns.scatterplot(x=df['Inches'], y=df['Price'])
plt.show()

# %%
#add a col for value 0 if it is not touch screen supported else 1
df['ScreenResolution'].value_counts()

# %%
df.drop(columns='TouchScreen',inplace=True)

# %%
df

# %%
#to chk if str "TouchScreen" is present in or not
#use apply to replace loop, and pass lambda func here which is call back fun and called for each row
df['TouchScreen']=df["ScreenResolution"].apply(lambda x: 1 if 'Touchscreen' in x else 0) 
df
# a='ismil'
# 'i' in a #in is conditional operator

# %%
# add a col for ssd if present in memory column there should 1 else 0
df['SSD']=df["Memory"].apply(lambda x:1 if 'SSD' in x else 0) 
df

# %%
#list 
#col=list
import matplotlib.pyplot as plt
import seaborn as sns
df['TouchScreen'].value_counts().plot(kind='bar')
# sns.barplot(x)
plt.show()

# %%
# c.value_counts()

sns.barplot(x=df['TouchScreen'], y=df['Price'])

# %%
# def add(a,b)
#     return a+b
# add(2,3)


#lambda expression:

#call back function, no need to call

df["IPS"].value_counts()
df['IPS']=df["ScreenResolution"].apply(lambda x:1 if 'IPS' in x else 0) 
df

# %%
#add two col for x_res, y_res,  seperating two values 

#a='25x45'
# new=a.split('x')
# 
# df["ScreenResolution"].str.split('x')[0]
# df["ScreenResolution"].str.split('x')[3]
df

# %%
df[['X_res','Y_res']]=df['ScreenResolution'].str.extract(r'(\d+)x(\d+)')  #\d+ =regular expressions
df
# ppsi calculate
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# x_res*y_res/inches
#create a new col ppsi, and its value will be

#first convert it into int i.e Type Casting
df.info()
df['Inches']=df['Inches'].astype('int32')   #here in int32 , 32 represent range or 
df['X_res']=df['X_res'].astype('int32') 
df['Y_res']=df['Y_res'].astype('int32')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   int32
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
#  11  X_res             1303 non-null   int32
#  12  Y_res             1303 non-null   int32
#  13  PPSI              1303 non-null   float64
# dtypes: float64(2), int32(3), object(9)
# memory usage: 127.4+ KB

# %%
df['PPSI']=(df['X_res']*df['Y_res'])/df['Inches']

# %%
df['PPSI']
# Out:
# 0       315076.923077
# 1        99692.307692
# 2       138240.000000
# 3       345600.000000
# 4       315076.923077
#             ...
# 1298    148114.285714
# 1299    443076.923077
# 1300     74934.857143
# 1301     69939.200000
# 1302     69939.200000
# Name: PPSI, Length: 1303, dtype: float64

# %%
#find rows where cpu contains core i5 and typename is ultrabook

#find the rows where os is window 7 and price is maximum

#fidn rows GPU contain Intel and company is asus and price is minimum


#nvr create new col in data analysis
#new col only make when u do preprocessing during model train and it's called feature engr

# %%
#==, in

#count values

df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
# df.loc[df['Cpu'].apply( lambda x: 'Core i5' in x)]
# df.loc[df['TypeName']=='Ultrabook']

df.loc[(df['Cpu'].str.contains('Core i5')) & (df['TypeName']=='Ultrabook')]
# Out:
#       Unnamed: 0 Company   TypeName  Inches  \
# 0              0   Apple  Ultrabook    13.3
# 1              1   Apple  Ultrabook    13.3
# 4              4   Apple  Ultrabook    13.3
# 7              7   Apple  Ultrabook    13.3
# 9              9    Acer  Ultrabook    14.0
# ...          ...     ...        ...     ...
# 1105        1105    Dell  Ultrabook    12.5
# 1127        1127      HP  Ultrabook    12.5
# 1188        1188    Dell  Ultrabook    13.3
# 1223        1223    Dell  Ultrabook    12.5
# 1234        1234   Apple  Ultrabook    11.6
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                               1440x900        Intel Core i5 1.8GHz  8GB
# 4     IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz  8GB
# 7                               1440x900        Intel Core i5 1.8GHz  8GB
# ...

# %%
# 2 
# df.loc[(df['OpSys']=='Windows 7')  & (df['Price']==df['Price'].max())]
row= df.loc[df['OpSys']=='Windows 7']
row.loc[row['Price']==row['Price'].max()]
# Out:
#      Unnamed: 0 Company     TypeName  Inches             ScreenResolution  \
# 749         749      HP  Workstation    17.3  IPS Panel Full HD 1920x1080
#
#                                Cpu   Ram     Memory                   Gpu  \
# 749  Intel Xeon E3-1535M v5 2.9GHz  16GB  256GB SSD  Nvidia Quadro M2000M
#
#          OpSys Weight      Price
# 749  Windows 7    3kg  233845.92

# %%
#harshat youtube

# %%
df.loc[(df['Gpu'].str.contains('Intel'))& (df['Company']=='Asus') & (df['Price']==df['Price'].min())]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Company, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price]
# Index: []

# %%
a=df.loc[(df['Gpu'].str.contains('Intel')) & (df['Company']=='Asus')]
a.loc[a['Price']==a['Price'].min()]

# string manipulation of lambda 

#change data in lower case to avoid case-senstive issue
# Out:
#     Unnamed: 0 Company TypeName  Inches ScreenResolution  \
# 20          20    Asus  Netbook    11.6         1366x768
#
#                             Cpu  Ram              Memory  \
# 20  Intel Atom x5-Z8350 1.44GHz  2GB  32GB Flash Storage
#
#                       Gpu       OpSys  Weight      Price
# 20  Intel HD Graphics 400  Windows 10  0.98kg  10224.432

# %%
y= df.loc[df['Gpu'].apply( lambda x: 'Intel' in x) & (df['Company'].apply(lambda x: 'Asus'in x))]
y.loc[y["Price"]==y["Price"].min()]
# Out:
#     Unnamed: 0 Company TypeName  Inches ScreenResolution  \
# 20          20    Asus  Netbook    11.6         1366x768
#
#                             Cpu  Ram              Memory  \
# 20  Intel Atom x5-Z8350 1.44GHz  2GB  32GB Flash Storage
#
#                       Gpu       OpSys  Weight      Price
# 20  Intel HD Graphics 400  Windows 10  0.98kg  10224.432

# %%
df['Cpu'].value_counts()  #U is lowest quality core, HQ has 8 core
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#create new cols
#create one col for cpu company
#create one columns for processor value
#create one for generation 
#create one column for GHz
a=df['Cpu'].str.split(" ")

# %%
a
# Out:
# 0                         [Intel, Core, i5, 2.3GHz]
# 1                         [Intel, Core, i5, 1.8GHz]
# 2                  [Intel, Core, i5, 7200U, 2.5GHz]
# 3                         [Intel, Core, i7, 2.7GHz]
# 4                         [Intel, Core, i5, 3.1GHz]
#                            ...
# 1298               [Intel, Core, i7, 6500U, 2.5GHz]
# 1299               [Intel, Core, i7, 6500U, 2.5GHz]
# 1300    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# 1301               [Intel, Core, i7, 6500U, 2.5GHz]
# 1302    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# Name: Cpu, Length: 1303, dtype: object

# %%
list=[]
for i in a:
    list.append(i[-1])
    
df['Ghz']=list

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
for i in a:
    i.pop()

# %%
list=[]
for i in a:
    list.append(i[0])

# %%
list
# Out:
# ['Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'AMD',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'AMD',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'AMD',
#  'AMD',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'AMD',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'AMD',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'Intel',
#  'AMD',
# ...

# %%
df['Cpu_comp']=list

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
for i in a:
    i.pop(0)

# %%
a
# Out:
# 1                         [Core, i5]
# 2                  [Core, i5, 7200U]
# 3                         [Core, i7]
# 4                         [Core, i5]
# 5                  [A9-Series, 9420]
#                     ...
# 1298               [Core, i7, 6500U]
# 1299               [Core, i7, 6500U]
# 1300    [Celeron, Dual, Core, N3050]
# 1301               [Core, i7, 6500U]
# 1302    [Celeron, Dual, Core, N3050]
# Name: Cpu, Length: 1302, dtype: object

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
#find the rows where ram is 8gb  also visualize the price

#numerical =  line plot
#category= bar plot

import seaborn as sns
test1=df.loc[df['Ram']=='8GB']
x=test1['Ram']
y=test1['Price']
sns.barplot(x=x, y=y) #one bar c/z one category 'Ram'
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
test1=df.loc[df['Ram']=='8GB']
x=test1['Ram']
y=test1['Price']
plt.pie(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       4 x=test1['Ram']
#       5 y=test1['Price']
# ----> 6 plt.pie(x=tes1)
#
# NameError: name 'tes1' is not defined

# %%
#find the rows where inches is greater than 8 and less than 16
# (df['Inches']>8) & (df['Inches']<16)   #true false ans
test = df.loc[(df['Inches']>8) & (df['Inches']<16) ]

#visulaize the plot of price and inches greater than 8 and less than 16

x=test['Inches']
y= test['Price']
sns.lineplot(x=x, y=y)
